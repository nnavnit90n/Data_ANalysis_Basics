# %% [markdown]
# # question ??
# 1. Countries with a happiness score of less than 5.0
# 2. Which is the unhappiest country in Sub-Saharan Africa?
# 3. Compare the Unhappiest and happiest countries in each region
# 4. Countries that became unhappy between 2015 to 2017
# 5. Find the country whose happiness decreased by the most amount

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df15=pd.read_csv('D:\\data analysis\\2015.csv')

# %%
df16=pd.read_csv('D:\\data analysis\\2016.csv')

# %%
df17=pd.read_csv('D:\\data analysis\\2017.csv')

# %%
df15.head(1)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738

# %%
df16.head(2)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 0                        0.44453     0.36171            2.73939
# 1                        0.41203     0.28083            2.69463

# %%
df17.head(1)
# Out:
#   Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0  Norway               1            7.537      7.594445     7.479556
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027

# %%
#Countries with a happiness score of less than 5.0?

#df15['Country']=df15[df15['Happiness Score']<5.0]
#df15

# %%
#df15[['Country', 'Happiness Score']].sort_values[by =( 'Happiness Score'<5.0)]

# %%
df15.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
df15.shape
# Out:
# (158, 12)

# %%
df16.shape
# Out:
# (157, 13)

# %%
df17.shape
# Out:
# (155, 12)

# %%
df15.set_index=('Country')

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
# Country                          158 non-null object
# Region                           158 non-null object
# Happiness Rank                   158 non-null int64
# Happiness Score                  158 non-null float64
# Standard Error                   158 non-null float64
# Economy (GDP per Capita)         158 non-null float64
# Family                           158 non-null float64
# Health (Life Expectancy)         158 non-null float64
# Freedom                          158 non-null float64
# Trust (Government Corruption)    158 non-null float64
# Generosity                       158 non-null float64
# Dystopia Residual                158 non-null float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
df15.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df15.duplicated().sum()
# Out:
# 0

# %%
df15.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#1.Countroe with happiness leass than 5?
df15=df15[df15["Happiness Score"]<5.0]
df15
# Out:
#                     Country                           Region  Happiness Rank  \
# 93               Mozambique               Sub-Saharan Africa              94
# 94                  Albania       Central and Eastern Europe              95
# 95   Bosnia and Herzegovina       Central and Eastern Europe              96
# 96                  Lesotho               Sub-Saharan Africa              97
# 97       Dominican Republic      Latin America and Caribbean              98
# ..                      ...                              ...             ...
# 153                  Rwanda               Sub-Saharan Africa             154
# 154                   Benin               Sub-Saharan Africa             155
# 155                   Syria  Middle East and Northern Africa             156
# 156                 Burundi               Sub-Saharan Africa             157
# 157                    Togo               Sub-Saharan Africa             158
#
# ...

# %%
# Countries withHappiness Score of company less than 5 (2016)?
df16=df16[df16["Happiness Score"]<5.0]
df16
# Out:
#                      Country                           Region  Happiness Rank  \
# 99                Tajikistan       Central and Eastern Europe             100
# 100                 Mongolia                     Eastern Asia             101
# 101                     Laos                Southeastern Asia             102
# 102                  Nigeria               Sub-Saharan Africa             103
# 103                 Honduras      Latin America and Caribbean             104
# 104                     Iran  Middle East and Northern Africa             105
# 105                   Zambia               Sub-Saharan Africa             106
# 106                    Nepal                    Southern Asia             107
# 107  Palestinian Territories  Middle East and Northern Africa             108
# 108                  Albania       Central and Eastern Europe             109
# 109               Bangladesh                    Southern Asia             110
# ...

# %%
# Countries with happiness less than 5 in 2017?
df17=df17[df17["Happiness.Score"]<5.0]
df17
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 98                      Nepal              99            4.962      5.067356
# 99                   Mongolia             100            4.955      5.021680
# 100              South Africa             101            4.829      4.929435
# 101                   Tunisia             102            4.805      4.884367
# 102   Palestinian Territories             103            4.775      4.881848
# 103                     Egypt             104            4.735      4.825134
# 104                  Bulgaria             105            4.714      4.803695
# 105              Sierra Leone             106            4.709      4.850643
# 106                  Cameroon             107            4.695      4.796541
# 107                      Iran             108            4.692      4.798225
# 108                   Albania             109            4.644      4.752464
# ...

# %%
df15.sort_values(by="Happiness Rank").max()
# Out:
# Country                                Zimbabwe
# Region                           Western Europe
# Happiness Rank                              158
# Happiness Score                           4.971
# Standard Error                          0.11068
# Economy (GDP per Capita)                1.15406
# Family                                   1.3006
# Health (Life Expectancy)                0.88213
# Freedom                                 0.66246
# Trust (Government Corruption)           0.55191
# Generosity                              0.79588
# Dystopia Residual                       3.05137
# dtype: object

# %%
#Which is the unhappiest country in Sub-Saharan Africa?(2015)
df15[df15["Region"]=="Sub-Saharan Africa"].sort_values(by='Happiness Rank').max()
# Out:
# Country                                    Zimbabwe
# Region                           Sub-Saharan Africa
# Happiness Rank                                  158
# Happiness Score                               4.971
# Standard Error                              0.11068
# Economy (GDP per Capita)                    1.06024
# Family                                      1.18468
# Health (Life Expectancy)                    0.46721
# Freedom                                     0.59201
# Trust (Government Corruption)               0.55191
# Generosity                                  0.37542
# Dystopia Residual                           3.05137
# dtype: object

# %%
# for 2016 which is the unhappiest country in Sub Saharan Africa??
df16[df16["Region"]=="Sub-Saharan Africa"].sort_values(by="Happiness Rank").max()
# Out:
# Country                                    Zimbabwe
# Region                           Sub-Saharan Africa
# Happiness Rank                                  157
# Happiness Score                               4.875
# Lower Confidence Interval                      4.75
# Upper Confidence Interval                         5
# Economy (GDP per Capita)                    1.15851
# Family                                      0.96053
# Health (Life Expectancy)                    0.40457
# Freedom                                      0.5432
# Trust (Government Corruption)               0.50521
# Generosity                                  0.41328
# Dystopia Residual                           3.01402
# dtype: object

# %%
#for 2017 which is the unhappiest country in  Sub saharan  Africa???
#df16.sort_values(by="Happiness Rank").min()
#Region s not mention in column
df17.sort_values(by="Happiness.Rank").max()
# Out:
# Country                          Zimbabwe
# Happiness.Rank                        155
# Happiness.Score                     4.962
# Whisker.high                      5.06736
# Whisker.low                       4.88832
# Economy..GDP.per.Capita.          1.19821
# Family                            1.49301
# Health..Life.Expectancy.          0.73116
# Freedom                          0.633376
# Generosity                       0.838075
# Trust..Government.Corruption.     0.45522
# Dystopia.Residual                 2.66846
# dtype: object

# %%
#3.Compare the Unhappiest and happiest countries in each region
df15_region=df15.groupby('Region')

# %%
df15_region["Happiness Rank"].describe().sort_values(by="mean", ascending=False).head(10)

# In 2015 data Easter Asia is the happiest region and Sub Saharn Africa is the unhappiest
# Out:
#                                  count        mean        std    min     25%  \
# Region
# Sub-Saharan Africa                36.0  133.083333  17.312877   94.0  121.50
# Southern Asia                      5.0  126.400000  17.023513  109.0  117.00
# Southeastern Asia                  3.0  124.333333  23.352373   99.0  114.00
# Middle East and Northern Africa    8.0  120.875000  19.037088  103.0  107.75
# Central and Eastern Europe         8.0  112.875000  15.459047   95.0  102.00
# Latin America and Caribbean        3.0  107.333333  10.692677   98.0  101.50
# Western Europe                     1.0  102.000000        NaN  102.0  102.00
# Eastern Asia                       1.0  100.000000        NaN  100.0  100.00
#
#                                    50%     75%    max
# Region
# Sub-Saharan Africa               137.5  147.25  158.0
# Southern Asia                    121.0  132.00  153.0
# Southeastern Asia                129.0  137.00  145.0
# ...

# %%
#df15_1=df15[df15['Region']=='Eastern Asia']
#df15_2=df15[df15["Region"]=='Western Europe']
#df15_3=df15[df15["Region"]=="Latin America and Caribbean"]
#df15_4=df15[df15["Region"]=="Central and Eastern Europe"]
#df15_5=df15[df15["Region"]=="Middle East and Northern Africa"]

# %%
df16_region=df16.groupby('Region')

# %%
df16_region["Happiness Rank"].describe().sort_values(by="mean",ascending=False).head(10)

# In 2016 Eastern Asia is the happiest region and the sub sharan africa is the unhappiest on the basis of happiness rank
# Out:
#                                  count        mean        std    min    25%  \
# Region
# Sub-Saharan Africa                35.0  133.942857  14.800522  103.0  124.5
# Middle East and Northern Africa    6.0  124.666667  21.574677  105.0  109.0
# Southern Asia                      5.0  121.200000  18.912959  107.0  110.0
# Southeastern Asia                  3.0  120.333333  19.035055  102.0  110.5
# Latin America and Caribbean        2.0  120.000000  22.627417  104.0  112.0
# Central and Eastern Europe         6.0  118.000000  11.171392  100.0  112.0
# Eastern Asia                       1.0  101.000000        NaN  101.0  101.0
#
#                                    50%     75%    max
# Region
# Sub-Saharan Africa               135.0  145.00  157.0
# Middle East and Northern Africa  116.0  140.25  156.0
# Southern Asia                    117.0  118.00  154.0
# Southeastern Asia                119.0  129.50  140.0
# Latin America and Caribbean      120.0  128.00  136.0
# ...

# %%
df17_region=df17.groupby('Country')

# %%
df_17=df17_region["Happiness.Rank"].describe().sort_values(by="mean",ascending=False).head(10)

# %%
df_17
# Out:
#                           count   mean  std    min    25%    50%    75%    max
# Country
# Central African Republic    1.0  155.0  NaN  155.0  155.0  155.0  155.0  155.0
# Burundi                     1.0  154.0  NaN  154.0  154.0  154.0  154.0  154.0
# Tanzania                    1.0  153.0  NaN  153.0  153.0  153.0  153.0  153.0
# Syria                       1.0  152.0  NaN  152.0  152.0  152.0  152.0  152.0
# Rwanda                      1.0  151.0  NaN  151.0  151.0  151.0  151.0  151.0
# Togo                        1.0  150.0  NaN  150.0  150.0  150.0  150.0  150.0
# Guinea                      1.0  149.0  NaN  149.0  149.0  149.0  149.0  149.0
# Liberia                     1.0  148.0  NaN  148.0  148.0  148.0  148.0  148.0
# South Sudan                 1.0  147.0  NaN  147.0  147.0  147.0  147.0  147.0
# Yemen                       1.0  146.0  NaN  146.0  146.0  146.0  146.0  146.0

# %%
df_17.tail(5)
# in 2017 Happiest country is Yemen and the unhappiest country is Central African Republic on the basis of happiness rank
# Out:
#              count   mean  std    min    25%    50%    75%    max
# Country
# Togo           1.0  150.0  NaN  150.0  150.0  150.0  150.0  150.0
# Guinea         1.0  149.0  NaN  149.0  149.0  149.0  149.0  149.0
# Liberia        1.0  148.0  NaN  148.0  148.0  148.0  148.0  148.0
# South Sudan    1.0  147.0  NaN  147.0  147.0  147.0  147.0  147.0
# Yemen          1.0  146.0  NaN  146.0  146.0  146.0  146.0  146.0

# %%
#4.Countries that became unhappy between 2015 to 2017

# %%
df15.head()
# Out:
#                    Country                       Region  Happiness Rank  \
# 93              Mozambique           Sub-Saharan Africa              94
# 94                 Albania   Central and Eastern Europe              95
# 95  Bosnia and Herzegovina   Central and Eastern Europe              96
# 96                 Lesotho           Sub-Saharan Africa              97
# 97      Dominican Republic  Latin America and Caribbean              98
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 93            4.971         0.07896                   0.08308  1.02626
# 94            4.959         0.05013                   0.87867  0.80434
# 95            4.949         0.06913                   0.83223  0.91916
# 96            4.898         0.09438                   0.37545  1.04103
# 97            4.885         0.07446                   0.89537  1.17202
#
#     Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
#5.Find the country whose happiness decreased by the most amount
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness_Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-060fbc2d2582> in <module>
# ----> 1 df=pd.DataFrame(df15[df15.Happiness_Score < 5.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Happiness_Score'
